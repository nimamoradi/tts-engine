# %% [markdown]
# this document will load file and make them ready to proccess

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd 'gdrive/My Drive'
# Out:
# /content/gdrive/My Drive

# %%
# !git clone https://github.com/NVIDIA/tacotron2
# Out:
# Cloning into 'tacotron2'...
# remote: Enumerating objects: 357, done.
# remote: Total 357 (delta 0), reused 0 (delta 0), pack-reused 357
# Receiving objects: 100% (357/357), 2.37 MiB | 12.50 MiB/s, done.
# Resolving deltas: 100% (187/187), done.

# %%
# !wget https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2
# Out:
# --2019-07-14 16:08:06--  http://!wget/
# Resolving !wget (!wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘!wget’
# --2019-07-14 16:08:06--  https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2
# Resolving data.keithito.com (data.keithito.com)... 174.138.79.61
# Connecting to data.keithito.com (data.keithito.com)|174.138.79.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2748572632 (2.6G) [application/octet-stream]
# Saving to: ‘LJSpeech-1.1.tar.bz2’
#
# LJSpeech-1.1.tar.bz 100%[===================>]   2.56G  40.7MB/s    in 49s
#
# 2019-07-14 16:08:55 (53.2 MB/s) - ‘LJSpeech-1.1.tar.bz2’ saved [2748572632/2748572632]
#
# FINISHED --2019-07-14 16:08:55--
# Total wall clock time: 50s
# Downloaded: 1 files, 2.6G in 49s (53.2 MB/s)

# %%
# !tar -xvjf 'LJSpeech-1.1.tar.bz2'
# !rm -i 'LJSpeech-1.1.tar.bz2'
# Out:
# rm: cannot remove 'LJSpeech-1.1.tar.bz2': No such file or directory

# %%
cd tacotron2
# Out:
# /content/gdrive/My Drive/tacotron2

# %%
# !git submodule init; git submodule update

# %%
# !sed -i 's,DUMMY,../LJSpeech-1.1/wavs,g' filelists/*.txt

# %%
# Out:
# ['content/tacotron2/filelists/ljs_audio_text_test_filelist.txt',
#  'content/tacotron2/filelists/ljs_audio_text_train_filelist.txt',
#  'content/tacotron2/filelists/ljs_audio_text_val_filelist.txt']
